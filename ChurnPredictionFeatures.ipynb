# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the csv file.

# %%
df = pd.read_csv('/content/ChurnPrediction (1).csv')

# %% [markdown]
# Explore the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   PastEmployee             1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   Education                1470 non-null   int64
#  6   EducationField           1470 non-null   object
#  7   EnvironmentSatisfaction  1470 non-null   int64
#  8   Gender                   1470 non-null   object
#  9   JobInvolvement           1470 non-null   int64
#  10  JobLevel                 1470 non-null   int64
#  11  JobRole                  1470 non-null   object
#  12  JobSatisfaction          1470 non-null   int64
#  13  MaritalStatus            1470 non-null   object
# ...

# %%
df
# Out:
#       Age PastEmployee     BusinessTravel       Department  DistanceFromHome  \
# 0      46           No      Travel_Rarely  Human Resources                 5
# 1      37          Yes      Travel_Rarely  Human Resources                 6
# 2      59           No         Non-Travel  Human Resources                 2
# 3      54           No         Non-Travel  Human Resources                26
# 4      26           No      Travel_Rarely  Human Resources                25
# ...   ...          ...                ...              ...               ...
# 1465   45           No      Travel_Rarely            Sales                20
# 1466   50          Yes      Travel_Rarely            Sales                28
# 1467   39           No      Travel_Rarely            Sales                24
# 1468   26           No      Travel_Rarely            Sales                 5
# 1469   49           No  Travel_Frequently            Sales                 2
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

ls = ['PastEmployee','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','OverTime']

for col in ls:
  df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#       Age  PastEmployee  BusinessTravel  Department  DistanceFromHome  \
# 0      46             0               2           0                 5
# 1      37             1               2           0                 6
# 2      59             0               0           0                 2
# 3      54             0               0           0                26
# 4      26             0               2           0                25
# ...   ...           ...             ...         ...               ...
# 1465   45             0               2           2                20
# 1466   50             1               2           2                28
# 1467   39             0               2           2                24
# 1468   26             0               2           2                 5
# 1469   49             0               1           2                 2
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  \
# ...

# %% [markdown]
# missing value analysis|

# %%
df.isnull().sum()
# Out:
# Age                        0
# PastEmployee               0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# # Experiment without feature selection

# %% [markdown]
# ## Separate dependent and independent variables

# %%
X = df.drop(columns=['PastEmployee'])
y = df['PastEmployee']

# %% [markdown]
# Split data into train and test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# Write a function for implementing the model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# Logistic Regression

# %%
def LR(X_train, X_test, y_train, y_test):
  logReg = LogisticRegression()
  logReg.fit(X_train, y_train)
  y_pred = logReg.predict(X_test)

  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test, y_pred))

# %% [markdown]
# Gaussian Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
def gaussian(X_train, X_test, y_train, y_test):
  gnb = GaussianNB()
  gnb.fit(X_train, y_train)
  y_pred = gnb.predict(X_test)

  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test, y_pred))

# %%
LR(X_train, X_test, y_train, y_test)
# Out:
# [[304   2]
#  [ 55   7]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       306
#            1       0.78      0.11      0.20        62
#
#     accuracy                           0.85       368
#    macro avg       0.81      0.55      0.56       368
# weighted avg       0.84      0.85      0.79       368
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
gaussian(X_train, X_test, y_train, y_test)
# Out:
# [[254  52]
#  [ 24  38]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       306
#            1       0.42      0.61      0.50        62
#
#     accuracy                           0.79       368
#    macro avg       0.67      0.72      0.68       368
# weighted avg       0.83      0.79      0.81       368

# %% [markdown]
# ## Feature selection using correlation matrix

# %%
df.corr()
# Out:
#                               Age  PastEmployee  BusinessTravel  Department  \
# Age                      1.000000     -0.159205        0.024751   -0.031882
# PastEmployee            -0.159205      1.000000        0.000074    0.063991
# BusinessTravel           0.024751      0.000074        1.000000   -0.009044
# Department              -0.031882      0.063991       -0.009044    1.000000
# DistanceFromHome        -0.001686      0.077924       -0.024469    0.017225
# Education                0.208034     -0.031373        0.000757    0.007996
# EducationField          -0.040873      0.026846        0.023724    0.013720
# EnvironmentSatisfaction  0.010146     -0.103369        0.004174   -0.019395
# Gender                  -0.036311      0.029453       -0.032981   -0.041583
# JobInvolvement           0.029820     -0.130016        0.039062   -0.024586
# JobLevel                 0.509604     -0.169105        0.019311    0.101963
# ...

# %%
cor = df.corr()
cor_target = abs(cor["PastEmployee"])

# %%
cor_target_org = cor["PastEmployee"]

# %%
cor_target_org
# Out:
# Age                       -0.159205
# PastEmployee               1.000000
# BusinessTravel             0.000074
# Department                 0.063991
# DistanceFromHome           0.077924
# Education                 -0.031373
# EducationField             0.026846
# EnvironmentSatisfaction   -0.103369
# Gender                     0.029453
# JobInvolvement            -0.130016
# JobLevel                  -0.169105
# JobRole                    0.067151
# JobSatisfaction           -0.103481
# MaritalStatus              0.162070
# MonthlyIncome             -0.159840
# NumCompaniesWorked         0.043494
# OverTime                   0.246118
# PercentSalaryHike         -0.013478
# PerformanceRating          0.002889
# StockOptionLevel          -0.137145
# TotalWorkingYears         -0.171063
# TrainingTimesLastYear     -0.059478
# WorkLifeBalance           -0.063939
# YearsAtCompany            -0.134392
# YearsInCurrentRole        -0.160545
# YearsSinceLastPromotion   -0.033019
# ...

# %%
cor_target
# Out:
# Age                        0.159205
# PastEmployee               1.000000
# BusinessTravel             0.000074
# Department                 0.063991
# DistanceFromHome           0.077924
# Education                  0.031373
# EducationField             0.026846
# EnvironmentSatisfaction    0.103369
# Gender                     0.029453
# JobInvolvement             0.130016
# JobLevel                   0.169105
# JobRole                    0.067151
# JobSatisfaction            0.103481
# MaritalStatus              0.162070
# MonthlyIncome              0.159840
# NumCompaniesWorked         0.043494
# OverTime                   0.246118
# PercentSalaryHike          0.013478
# PerformanceRating          0.002889
# StockOptionLevel           0.137145
# TotalWorkingYears          0.171063
# TrainingTimesLastYear      0.059478
# WorkLifeBalance            0.063939
# YearsAtCompany             0.134392
# YearsInCurrentRole         0.160545
# YearsSinceLastPromotion    0.033019
# ...

# %%
chosen_features = cor_target[cor_target>0.1]

# %%
chosen_features
# Out:
# Age                        0.159205
# PastEmployee               1.000000
# EnvironmentSatisfaction    0.103369
# JobInvolvement             0.130016
# JobLevel                   0.169105
# JobSatisfaction            0.103481
# MaritalStatus              0.162070
# MonthlyIncome              0.159840
# OverTime                   0.246118
# StockOptionLevel           0.137145
# TotalWorkingYears          0.171063
# YearsAtCompany             0.134392
# YearsInCurrentRole         0.160545
# YearsWithCurrManager       0.156199
# Name: PastEmployee, dtype: float64

# %%
ls1 = list(chosen_features.index.values)
# .index().tolist()

# %%
ls1
# Out:
# ['Age',
#  'PastEmployee',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'OverTime',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsWithCurrManager']

# %%
df_new = df[ls1]

# %%
df_new
# Out:
#       Age  PastEmployee  EnvironmentSatisfaction  JobInvolvement  JobLevel  \
# 0      46             0                        2               3         2
# 1      37             1                        3               3         1
# 2      59             0                        3               2         5
# 3      54             0                        4               4         4
# 4      26             0                        3               3         1
# ...   ...           ...                      ...             ...       ...
# 1465   45             0                        4               3         2
# 1466   50             1                        4               2         3
# 1467   39             0                        2               2         4
# 1468   26             0                        4               2         1
# 1469   49             0                        4               2         2
#
#       JobSatisfaction  MaritalStatus  MonthlyIncome  OverTime  \
# ...

# %%
X_feat = df_new.drop(columns=['PastEmployee'])
y = df['PastEmployee']

# %%
X_train_feat, X_test_feat, y_train, y_test = train_test_split(X_feat, y, test_size = 0.25, random_state = 42)

# %%
LR(X_train_feat, X_test_feat, y_train, y_test)
# Out:
# [[306   0]
#  [ 61   1]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       306
#            1       1.00      0.02      0.03        62
#
#     accuracy                           0.83       368
#    macro avg       0.92      0.51      0.47       368
# weighted avg       0.86      0.83      0.76       368
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
gaussian(X_train_feat, X_test_feat, y_train, y_test)
# Out:
# [[257  49]
#  [ 26  36]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87       306
#            1       0.42      0.58      0.49        62
#
#     accuracy                           0.80       368
#    macro avg       0.67      0.71      0.68       368
# weighted avg       0.83      0.80      0.81       368

# %% [markdown]
# ## Scale the dataset

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ### Standardize the data

# %%
std = StandardScaler()
X_std = std.fit_transform(X)

# %% [markdown]
# Standard scaler with original data

# %%
X_train_std, X_test_std, y_train, y_test = train_test_split(X_std, y, test_size = 0.25, random_state = 42)

# %%
LR(X_train_std, X_test_std, y_train, y_test)
# Out:
# [[297   9]
#  [ 44  18]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       306
#            1       0.67      0.29      0.40        62
#
#     accuracy                           0.86       368
#    macro avg       0.77      0.63      0.66       368
# weighted avg       0.84      0.86      0.83       368

# %%
gaussian(X_train_std, X_test_std, y_train, y_test)
# Out:
# [[255  51]
#  [ 23  39]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       306
#            1       0.43      0.63      0.51        62
#
#     accuracy                           0.80       368
#    macro avg       0.68      0.73      0.69       368
# weighted avg       0.84      0.80      0.81       368

# %% [markdown]
# Standard scaler with serlected features

# %%
X_std_feat = std.fit_transform(X_feat)
X_train_std_feat, X_test_std_feat, y_train, y_test = train_test_split(X_std_feat, y, test_size = 0.25, random_state = 42)

# %%
LR(X_train_std_feat, X_test_std_feat, y_train, y_test)
# Out:
# [[299   7]
#  [ 41  21]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       306
#            1       0.75      0.34      0.47        62
#
#     accuracy                           0.87       368
#    macro avg       0.81      0.66      0.70       368
# weighted avg       0.86      0.87      0.85       368

# %%
gaussian(X_train_std_feat, X_test_std_feat, y_train, y_test)
# Out:
# [[255  51]
#  [ 26  36]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       306
#            1       0.41      0.58      0.48        62
#
#     accuracy                           0.79       368
#    macro avg       0.66      0.71      0.68       368
# weighted avg       0.82      0.79      0.80       368

# %% [markdown]
# ### Min_Max Scaling

# %%
min_max = MinMaxScaler()
X_mm = min_max.fit_transform(X)

# %%
X_train_mm, X_test_mm, y_train, y_test = train_test_split(X_mm, y, test_size = 0.25, random_state = 42)

# %%
LR(X_train_mm, X_test_mm, y_train, y_test)
# Out:
# [[299   7]
#  [ 44  18]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       306
#            1       0.72      0.29      0.41        62
#
#     accuracy                           0.86       368
#    macro avg       0.80      0.63      0.67       368
# weighted avg       0.85      0.86      0.84       368

# %%
gaussian(X_train_mm, X_test_mm, y_train, y_test)
# Out:
# [[255  51]
#  [ 23  39]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87       306
#            1       0.43      0.63      0.51        62
#
#     accuracy                           0.80       368
#    macro avg       0.68      0.73      0.69       368
# weighted avg       0.84      0.80      0.81       368

# %%
X_mm_feat = min_max.fit_transform(X_feat)
X_train_mm_feat, X_test_mm_feat, y_train, y_test = train_test_split(X_mm_feat, y, test_size = 0.25, random_state = 42)

# %%
LR(X_train_mm_feat, X_test_mm_feat, y_train, y_test)
# Out:
# [[299   7]
#  [ 43  19]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       306
#            1       0.73      0.31      0.43        62
#
#     accuracy                           0.86       368
#    macro avg       0.80      0.64      0.68       368
# weighted avg       0.85      0.86      0.84       368

# %%
gaussian(X_train_mm_feat, X_test_mm_feat, y_train, y_test)
# Out:
# [[255  51]
#  [ 26  36]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       306
#            1       0.41      0.58      0.48        62
#
#     accuracy                           0.79       368
#    macro avg       0.66      0.71      0.68       368
# weighted avg       0.82      0.79      0.80       368
